# %% [markdown]
# # TASK 1
# **3.3. Snakemake $Stepik$**

# %% [markdown]
# ```
# rule all:
#     input: "input/input"
#     output: "output/output"
#     shell: "cat {input} | wc -w > {output}"
# ```

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # TASK 2
# **3.4. Snakemake $Stepik$**

# %% [markdown]
# ```
# import os
# from collections import defaultdict
#
# def gen(folder1, folder2):
#     return ["{}/{}".format(folder1, n) for n in os.listdir(folder2)]
#
# rule all:
#     input: gen("output", "input")
#     output: ".status"
#     shell: "touch {output}"
#
# rule count:
#     input: "input/{file}"
#     output: "output/{file}"
#     run:
#         with open(str(input), "r") as inp:
#             count_d = defaultdict(int)
#             for line in inp:
#                 line = line.strip().lower()
#                 for s in line:
#                     count_d[s] += 1
#         with open(str(output), "w") as out:
#             for el in sorted(list(count_d.keys())):
#                 out.write("{}: {}\n".format(el, str(count_d[el])))
# ```

# %% [markdown]
# Rul
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
